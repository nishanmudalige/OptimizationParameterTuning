# %%
import pandas as pd
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', 20)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
error_cols = ["error_problem", "error_solver", "error_type"]
raw_df = pd.read_csv("./datasets/raw.csv")

# %%
data = pd.read_csv("./datasets/final.csv")
data[data["status"].notna()]
data["status"].value_counts()
# Out:
# status
# first_order    21487
# Name: count, dtype: int64

# %%
list(data.columns)
# Out:
# ['nvmops',
#  'objective',
#  'eval_duration_solver',
#  'extract_duration_solver',
#  'stats_elapsed_time',
#  'name',
#  'dual_feas',
#  'status',
#  'timed_bytes',
#  'timed_time',
#  'timed_gctime',
#  'nlp_warmup_time',
#  'mem',
#  'neval_grad',
#  'iter',
#  'source_solver',
#  'nvar',
#  'problem',
#  'neval_obj',
#  'timestamp_solver',
#  'error_solver',
#  'vector_type',
#  'extract_duration_problem',
#  'highest_degree (ExprTree)',
#  'nln_nnzj',
#  'adbackend_hessian_backend_type',
#  'minimize',
#  'count_plus_minus',
#  'alloc_obj',
#  'jtprod_available',
#  'has_equalities',
#  'time_hprod',
#  'adbackend_jprod_residual_backend_type',
#  'adbackend_ghjvprod_backend_type',
#  'nnln',
#  'jprod_residual_available',
#  'nlvb',
#  'nlvo',
#  'nlp_type',
#  'unconstrained',
#  'adbackend_jacobian_backend_type',
#  'adbackend_jprod_backend_type',
#  'hprod_residual_available',
#  'jac_available',
#  'hess_residual_available',
#  'adbackend_gradient_backend_type',
#  'float_type',
#  'ncon',
#  'is_nls',
#  'nnzo',
#  'nlvc',
#  'tree_length',
#  'count_trigonometric_function',
#  'matrix_free',
#  'nlin',
#  'time_obj',
#  'tree_depth',
#  'is_constant (ExprTree)',
#  'nnzj',
#  'alloc_hprod',
#  'adbackend_jacobian_residual_backend_type',
#  'generator',
#  'alloc_hess',
#  'hess_available',
#  'count_exponential_function',
#  'islp',
#  'count_op_function',
#  'error_problem',
#  'adbackend_hprod_residual_backend_type',
#  'equality_constrained',
#  'time_grad',
#  'source_problem',
#  'has_bounds',
#  'grad_available',
#  'clinvals_nnz',
#  'jac_residual_available',
#  'bound_constrained',
#  'jprod_available',
#  'eval_duration_problem',
#  'adbackend_hessian_residual_backend_type',
#  'nequ',
#  'adbackend_jtprod_residual_backend_type',
#  'has_inequalities',
#  'is_linear (ExprTree)',
#  'linearly_constrained',
#  'adbackend_jtprod_backend_type',
#  'hprod_available',
#  'jtprod_residual_available',
#  'alloc_grad',
#  'inequality_constrained',
#  'time_hess',
#  'lin_nnzj',
#  'nnzh',
#  'timestamp_problem',
#  'adbackend_hprod_backend_type',
#  'error_type',
#  'total_alloc']

# %%
meta_df = pd.read_csv("./datasets/problem_metadata.csv")
meta_df.head(10)
list(meta_df.columns)
# Out:
# ['vector_type',
#  'extract_duration',
#  'highest_degree (ExprTree)',
#  'nln_nnzj',
#  'adbackend_hessian_backend_type',
#  'minimize',
#  'count_plus_minus',
#  'alloc_obj',
#  'jtprod_available',
#  'has_equalities',
#  'nvar',
#  'time_hprod',
#  'adbackend_jprod_residual_backend_type',
#  'adbackend_ghjvprod_backend_type',
#  'nnln',
#  'jprod_residual_available',
#  'nlvb',
#  'nlvo',
#  'name',
#  'nlp_type',
#  'unconstrained',
#  'adbackend_jacobian_backend_type',
#  'adbackend_jprod_backend_type',
#  'hprod_residual_available',
#  'jac_available',
#  'hess_residual_available',
#  'adbackend_gradient_backend_type',
#  'float_type',
#  'ncon',
#  'is_nls',
#  'nnzo',
#  'problem',
#  'nlvc',
#  'tree_length',
#  'count_trigonometric_function',
#  'matrix_free',
#  'nlin',
#  'time_obj',
#  'tree_depth',
#  'is_constant (ExprTree)',
#  'nnzj',
#  'alloc_hprod',
#  'adbackend_jacobian_residual_backend_type',
#  'generator',
#  'alloc_hess',
#  'hess_available',
#  'count_exponential_function',
#  'islp',
#  'count_op_function',
#  'error',
#  'adbackend_hprod_residual_backend_type',
#  'equality_constrained',
#  'time_grad',
#  'source',
#  'has_bounds',
#  'grad_available',
#  'clinvals_nnz',
#  'jac_residual_available',
#  'bound_constrained',
#  'jprod_available',
#  'eval_duration',
#  'adbackend_hessian_residual_backend_type',
#  'nequ',
#  'adbackend_jtprod_residual_backend_type',
#  'has_inequalities',
#  'is_linear (ExprTree)',
#  'linearly_constrained',
#  'adbackend_jtprod_backend_type',
#  'hprod_available',
#  'jtprod_residual_available',
#  'alloc_grad',
#  'inequality_constrained',
#  'time_hess',
#  'lin_nnzj',
#  'nnzh',
#  'timestamp',
#  'adbackend_hprod_backend_type',
#  'error_type']

# %%
solver_df = pd.read_csv("./datasets/solver_runtimes.csv")
solver_df.head(10)
list(solver_df.columns)
# Out:
# ['nvmops',
#  'objective',
#  'eval_duration',
#  'extract_duration',
#  'stats_elapsed_time',
#  'name',
#  'dual_feas',
#  'status',
#  'timed_bytes',
#  'timed_time',
#  'timed_gctime',
#  'nlp_warmup_time',
#  'mem',
#  'neval_grad',
#  'iter',
#  'source',
#  'nvar',
#  'problem',
#  'neval_obj',
#  'timestamp',
#  'error']

# %%
data["name"]
# Out:
# 0         dqdrtic
# 1         dqdrtic
# 2         dqdrtic
# 3         dqdrtic
# 4         dqdrtic
#            ...
# 21482    srosenbr
# 21483    srosenbr
# 21484    srosenbr
# 21485    srosenbr
# 21486    srosenbr
# Name: name, Length: 21487, dtype: str

# %% [markdown]
# ## Get a sense of how many problems are left unsolved

# %%
bins = [0, 95, 100, 1_000, 10_000, 100_000, 500_000]
data["nvar_bin"] = pd.cut(data["nvar"], bins=bins)
bin_counts = data["nvar_bin"].value_counts().sort_index()
print(bin_counts)
# Out:
# nvar_bin
# (0, 95]                0
# (95, 100]           7600
# (100, 1000]         7394
# (1000, 10000]       4478
# (10000, 100000]     2015
# (100000, 500000]       0
# Name: count, dtype: int64

# %% [markdown]
# ## Timeout is the main cause of error. We will assign it with the maxtime

# %%
g = error_df.groupby(["name", "nvar"])

summary = g.agg(
    mem_tried=("mem", "nunique"),
    n_failed=("error_solver", lambda s: s.notna().sum()),
    n_timeout=("error_solver", lambda s: s.astype(str).str.contains("timeout|max_time|time limit", case=False, na=False).sum()),
).reset_index()

summary["all_failed"] = summary["n_failed"] == summary["mem_tried"]
summary["all_timeout"] = summary["n_timeout"] == summary["mem_tried"]

# summary[summary["all_failed"]]
summary[summary["all_timeout"]].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 g = error_df.groupby(["name", "nvar"])
#       3 summary = g.agg(
#       4     mem_tried=("mem", "nunique"),
#       5     n_failed=("error_solver", lambda s: s.notna().sum()),
#       6     n_timeout=("error_solver", lambda s: s.astype(str).str.contains("timeout|max_time|time limit", case=False, na=False).sum()),
#       7 ).reset_index()
#       9 summary["all_failed"] = summary["n_failed"] == summary["mem_tried"]
#
# NameError: name 'error_df' is not defined

# %%
error_df = pd.read_csv("error.csv")
error_df[error_cols]
error_df["error_type"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
data["extract_duration_solver"].describe()
# Out:
# count    21802.000000
# mean       231.156322
# std        623.581489
# min          0.010550
# 25%          0.028606
# 50%          1.111176
# 75%         38.399035
# max       4836.617282
# Name: extract_duration_solver, dtype: float64

# %%
data["extract_duration_problem"].describe()
# Out:
# count    21802.000000
# mean       917.739506
# std       3005.186915
# min          0.344133
# 25%          3.930943
# 50%         15.751056
# 75%        157.154165
# max      29930.254929
# Name: extract_duration_problem, dtype: float64

# %%
data["stats_elapsed_time"].describe()
# Out:
# count    21802.000000
# mean       230.308125
# std        618.916504
# min          0.000135
# 25%          0.017087
# 50%          1.099377
# 75%         38.387239
# max       3600.000000
# Name: stats_elapsed_time, dtype: float64

# %%
data["eval_duration_solver"].describe() # time to instantiate the problem
# Out:
# count    21802.000000
# mean         0.303081
# std          0.134064
# min          0.000418
# 25%          0.267699
# 50%          0.309126
# 75%          0.365034
# max          0.829645
# Name: eval_duration_solver, dtype: float64

# %%
data["eval_duration_problem"].describe() # time to instantiate before problem and extract features
# Out:
# count    21802.000000
# mean         2.660228
# std          1.879221
# min          0.011663
# 25%          0.865562
# 50%          3.130428
# 75%          3.688310
# max          9.299191
# Name: eval_duration_problem, dtype: float64

# %%
col_lst = [column for column in data.columns]
# for col in col_lst:
#     print(col)
col_lst
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 col_lst = [column for column in data.columns]
#       2 # for col in col_lst:
#       3 #     print(col)
#       4 col_lst
#
# NameError: name 'data' is not defined

# %%
success_counts = data.groupby("mem")["solved"].sum().sort_values(ascending=False)
success_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 success_counts = data.groupby("mem")["solved"].sum().sort_values(ascending=False)
#       2 success_counts
#
# File ~/projects/AutoJSOSolverSelection.jl/venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File ~/projects/AutoJSOSolverSelection.jl/venv/lib/python3.12/site-packages/pandas/core/base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# --> 228         raise KeyError(f"Column not found: {key}")
#     229     ndim = self.obj[key].ndim
#     230     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: solved'

# %%
status_counts = data["status"].value_counts()

plt.figure()
plt.bar(status_counts.index.astype(str), status_counts.values)
plt.xlabel("Status")
plt.ylabel("Count")
plt.title("Solver Status Distribution")
plt.show()

# %%
data["stats_elapsed_time"].describe()
# Out:
# count    21802.000000
# mean       230.308125
# std        618.916504
# min          0.000135
# 25%          0.017087
# 50%          1.099377
# 75%         38.387239
# max       3600.000000
# Name: stats_elapsed_time, dtype: float64

# %%
data["is_constant (ExprTree)"].dropna().value_counts()
# Out:
# is_constant (ExprTree)
# False    21802
# Name: count, dtype: int64

# %%
data["is_linear (ExprTree)"].value_counts()
# Out:
# is_linear (ExprTree)
# False    21802
# Name: count, dtype: int64

# %%
x = data["highest_degree (ExprTree)"].dropna()
counts = x.value_counts().sort_index()
plt.figure()
plt.bar(counts.index.astype(str), counts.values)
plt.xlabel("Highest Degree")
plt.ylabel("Frequency")
plt.show()

# %%
x = data["tree_length"].dropna()
plt.figure()
plt.title("Distribution of Highest Degree (ExprTree) raw data")
plt.hist(x, bins="scott")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

x = data["tree_length"].dropna()
x = x[x <= 25000]
plt.figure()
plt.title("Distribution of Highest Degree (ExprTree) raw data [0,25000]")
plt.hist(x, bins="scott")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

ax = sns.histplot(np.log10(x), bins=40, kde=True)
ax.set_title("Log-scaled Distribution of Highest Degree (ExprTree) raw data")
# Out:
# Text(0.5, 1.0, 'Log-scaled Distribution of Highest Degree (ExprTree) raw data')

# %%
x = data["tree_depth"].dropna()
counts = x.value_counts().sort_index()
plt.figure()
plt.title("Distribution of tree_depth")
plt.bar(counts.index.astype(str), counts.values)
plt.xlabel("Tree Depth")
plt.ylabel("Frequency")
plt.show()

# %%
x = data["count_plus_minus"].dropna()
plt.figure()
plt.title("Distribution of count_plus_minus raw data")
plt.hist(x, bins="scott")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

x = data["count_plus_minus"].dropna()
x = x[x <= 100000]
plt.figure()
plt.title("Distribution of count_plus_minus raw data [0,100000]")
plt.hist(x, bins="scott")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

ax = sns.histplot(np.log10(x), bins=40, kde=True)
ax.set_title("Log-scaled Distribution of count_plus_minus raw data")
# Out:
# Text(0.5, 1.0, 'Log-scaled Distribution of count_plus_minus raw data')

# %%
x = data["count_trigonometric_function"].dropna()
count = x.value_counts().sort_index()
plt.title("Distribution of count_trignometric_function")
plt.bar(counts.index.astype(str), counts.values)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
x = data["count_exponential_function"].dropna()
count = x.value_counts().sort_index()
plt.title("Distribution of count_exponential_function")
plt.bar(counts.index.astype(str), counts.values)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
x = data["count_op_function"].dropna()
count = x.value_counts().sort_index()
plt.title("Distribution of count_op_function")
plt.bar(counts.index.astype(str), counts.values)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
x = data["neval_obj"].dropna()

sns.boxplot(y=np.log10(x))
plt.ylabel("log10(neval_obj)")
plt.show()

# %%
x = data["neval_grad"].dropna()

sns.boxplot(y=np.log10(x))
plt.ylabel("log10(neval_grad)")
plt.show()

# %%
x = data["time_obj"].dropna()

sns.boxplot(y=x)
plt.ylabel("neval_obj")
plt.show()

# %%
x = data["time_grad"].dropna()

sns.boxplot(y=np.log10(x))
plt.ylabel("log10(time_grad)")
plt.show()

# %%
x = data["alloc_grad"].dropna()
x = x[x > 0]

sns.boxplot(y=np.log10(x))
plt.ylabel("log10(alloc_grad)")
plt.show()

# %%
x = data["alloc_grad"].dropna()
x = x[x > 0]

sns.boxplot(y=np.log10(x))
plt.ylabel("log10(alloc_grad)")
plt.show()

# %%
x = data["eval_duration_problem"].dropna()

sns.boxplot(y=x)
plt.ylabel("eval_duration_problem")
plt.show()

# %%
x = data["eval_duration_solver"].dropna()
x = x[x > 0]

sns.boxplot(y=x)
plt.ylabel("eval_duration_solver")
plt.show()

# %%
x = data["stats_elapsed_time"]
x = x[x>0]

sns.boxplot(y=np.log10(x))
plt.ylabel("stats_elapsed_time")
plt.show()

# %%
x = data["total_alloc"]
x = x[x>0]
x.describe()

sns.boxplot(y=np.log10(x))
plt.ylabel("total_alloc")
plt.show()

# %%
data["stats_elapsed_time"].describe()
# Out:
# count    31496.000000
# mean       106.206499
# std        416.986494
# min          0.000000
# 25%          0.000651
# 50%          0.031088
# 75%          4.852586
# max       3597.119879
# Name: stats_elapsed_time, dtype: float64

# %%
status_table = (
    data["status"]
    .dropna()
    .astype(str)                  
    .value_counts()
    .rename_axis("status")
    .reset_index(name="count")
)
status_table["proportion"] = status_table["count"] / status_table["count"].sum()
status_table
# Out:
#    index       status  count  proportion
# 0      0  first_order  31238    0.984246
# 1      1    unbounded    500    0.015754

# %%
plt.figure()
plt.bar(status_table["status"], status_table["count"])
plt.yscale("log")
plt.xlabel("Status")
plt.ylabel("Count (log scale)")
plt.title("Solver Status Distribution (log scale)")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()

# %%
x = data["timed_bytes"]
x.describe()

sns.histplot(x=np.log1p(x))
# plt.ylabel("timed_bytes")
plt.show()

# %%
x = data["timed_time"]
x.describe()

sns.boxplot(y=np.log10(x))
plt.ylabel("timed_time")
plt.show()

# %%
x = data["timed_gctime"]
x.describe()

sns.boxplot(y=np.log10(x + 0.00000000000001))
plt.ylabel("timed_gctime")
plt.show()

# %%
x = data["stats_elapsed_time"]
x.describe()

sns.boxplot(y=np.log10(x + 0.00000000000001))
plt.ylabel("stats_elapsed_time")
plt.show()
