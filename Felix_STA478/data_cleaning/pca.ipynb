# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("./datasets/final_cleaned.csv")
# Out:
# /var/folders/sw/_ncn72vj5_3cwxr20z6xmg6h0000gn/T/ipykernel_21848/609775122.py:1: DtypeWarning: Columns (40,41,42,51,55,60,63,70,71,74,76,77,80,81,85,87,89,91) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./datasets/final_cleaned.csv")
# Index(['alloc_grad', 'stats_elapsed_time', 'count_plus_minus',
#        'count_exponential_function', 'mem', 'time_grad', 'alloc_obj', 'nvar',
#        'total_alloc', 'problem', 'neval_grad', 'tree_depth', 'alloc_hprod',
#        'timed_bytes', 'extract_duration_problem', 'eval_duration_problem',
#        'tree_length', 'time_obj', 'neval_obj', 'highest_degree (ExprTree)',
#        'count_op_function', 'name', 'count_trigonometric_function', 'index',
#        'nvmops', 'objective', 'eval_duration_solver',
#        'extract_duration_solver', 'dual_feas', 'status', 'timed_time',
#        'timed_gctime', 'nlp_warmup_time', 'iter', 'source_solver',
# ...
