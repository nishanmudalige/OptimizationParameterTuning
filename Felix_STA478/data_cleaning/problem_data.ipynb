# %%
import pandas as pd
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', 20)

# %%
df = pd.read_csv("./datasets/problem_metadata.csv")
df.sort_values(by=["name","nvar", "problem"])
df["nvar"].value_counts()
# Out:
# nvar
# 100.0       65
# 1000.0      62
# 10000.0     51
# 100000.0    48
# 9999.0      12
# 99999.0     12
# 99.0        12
# 999.0       12
# 99856.0      3
# 961.0        3
# Name: count, dtype: int64

# %%
df["time_grad"].isna().count()
# Out:
# np.int64(280)

# %%
df["time_obj"]
# Out:
# 0      0.082931
# 1      0.098302
# 2      0.259961
# 3      0.471347
# 4      0.441167
#          ...
# 275    0.253384
# 276    0.187980
# 277    0.571396
# 278    1.657196
# 279    0.117654
# Name: time_obj, Length: 280, dtype: float64

# %%
df["nvar"].unique()
df["nvar"].value_counts().sort_index()
# Out:
# nvar
# 99.0        12
# 100.0       65
# 961.0        3
# 999.0       12
# 1000.0      62
# 9999.0      12
# 10000.0     51
# 99856.0      3
# 99999.0     12
# 100000.0    48
# Name: count, dtype: int64

# %%
list(df.columns)
# Out:
# ['vector_type',
#  'extract_duration',
#  'highest_degree (ExprTree)',
#  'nln_nnzj',
#  'adbackend_hessian_backend_type',
#  'minimize',
#  'count_plus_minus',
#  'alloc_obj',
#  'jtprod_available',
#  'has_equalities',
#  'nvar',
#  'time_hprod',
#  'adbackend_jprod_residual_backend_type',
#  'adbackend_ghjvprod_backend_type',
#  'nnln',
#  'jprod_residual_available',
#  'nlvb',
#  'nlvo',
#  'name',
#  'nlp_type',
#  'unconstrained',
#  'adbackend_jacobian_backend_type',
#  'adbackend_jprod_backend_type',
#  'hprod_residual_available',
#  'jac_available',
#  'hess_residual_available',
#  'adbackend_gradient_backend_type',
#  'float_type',
#  'ncon',
#  'is_nls',
#  'nnzo',
#  'problem',
#  'nlvc',
#  'tree_length',
#  'count_trigonometric_function',
#  'matrix_free',
#  'nlin',
#  'time_obj',
#  'tree_depth',
#  'is_constant (ExprTree)',
#  'nnzj',
#  'alloc_hprod',
#  'adbackend_jacobian_residual_backend_type',
#  'generator',
#  'alloc_hess',
#  'hess_available',
# ...
